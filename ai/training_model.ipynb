# %%
# 1. 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')

# 2. YOLOv8 라이브러리
# !pip install ultralytics
# Out:
# Mounted at /content/drive
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 29.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# 1. YOLOv8 모델
model = YOLO('/content/drive/MyDrive/SkinAI/YOLO_Training_Result/skin_disease_model/weights/last.pt')

# 2. 데이터셋 경로
data_path = '/content/drive/MyDrive/SkinAI/YOLO_Dataset_Leak_Free'

# 3. 모델 학습 시작
# results = model.train(
# data=data_path,
#     epochs=50,             # 에포크 수
#     patience=15,            # 조기 종료 (15 Epoch 동안 개선 없으면 중단)
#     batch=32,               # 배치 사이즈
#     lr0=0.01,               # 초기 학습률
#     optimizer='SGD',        # 옵티마이저
#     dropout=0.3,            # 드롭아웃 (0.2 ~ 0.5 조절)
#     imgsz=224,              # 이미지 입력 사이즈
#     project='/content/drive/MyDrive/SkinAI/YOLO_Training_Result', # 저장 위치
#     name='skin_disease_model', # 저장 폴더 이름
#     exist_ok=True           # 덮어쓰기 허용
# )
results = model.train(resume=True)

print("학습 완료")
# Out:
# Ultralytics 8.4.40 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
